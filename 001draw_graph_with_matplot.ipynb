# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = 2.461
a1 = np.array([a*(3**0.5)/2, a/2])
a2 = np.array([a*(3**0.5)/2, -a/2])
b1 = np.array([-2*a/3, 0])
b2 = np.array([((3**0.5)/2-2/3)*a, a/2])
b3 = np.array([((3**0.5)/2-2/3)*a, -a/2])
plt.plot([0, a1[0]], [0, a1[1]])
plt.plot([0, a2[0]], [0, a2[1]])
plt.plot([0, b1[0]], [0, b1[1]])
plt.plot([0, b2[0]], [0, b2[1]])
plt.plot([0, b3[0]], [0, b3[1]])
plt.show()

# %%
a = 2.461
a1 = np.array([a*(3**0.5)/2, a/2])
a2 = np.array([a*(3**0.5)/2, -a/2])
b1 = np.array([-2*a/3, 0])
b2 = np.array([((3**0.5)/2-2/3)*a, a/2])
b3 = np.array([((3**0.5)/2-2/3)*a, -a/2])
plt.axes().set_aspect('equal')
for i in range(10):
    for j in range(10):
        plt.scatter(i*a1[0]+j*a2[0], i*a1[1]+j*a2[1], color = "black")
        plt.scatter(2*a/3+i*a1[0]+j*a2[0], i*a1[1]+j*a2[1], color = "black")
        plt.plot([2*a/3+i*a1[0]+j*a2[0], 2*a/3+i*a1[0]+j*a2[0]+b1[0]], [i*a1[1]+j*a2[1], i*a1[1]+j*a2[1]+b1[1]], color = "black")
        plt.plot([2*a/3+i*a1[0]+j*a2[0], 2*a/3+i*a1[0]+j*a2[0]+b2[0]], [i*a1[1]+j*a2[1], i*a1[1]+j*a2[1]+b2[1]], color = "black")
        plt.plot([2*a/3+i*a1[0]+j*a2[0], 2*a/3+i*a1[0]+j*a2[0]+b3[0]], [i*a1[1]+j*a2[1], i*a1[1]+j*a2[1]+b3[1]], color = "black")


plt.show()

# %%
a = 2.461
a1 = np.array([a*(3**0.5)/2, a/2])
a2 = np.array([a*(3**0.5)/2, -a/2])

for i in range(10):
    plt.scatter(i*a1[0], i*a1[1], color = "red")
    plt.scatter(i*a2[0], i*a2[1], color = "blue")
    plt.scatter(2*a/3+i*a1[0], i*a1[1], color = "yellow")
    plt.scatter(2*a/3+i*a2[0], i*a2[1], color = "black")
plt.show()

# %%
a = 2.461
a1 = np.array([a*(3**0.5)/2, a/2])
a2 = np.array([a*(3**0.5)/2, -a/2])
plt.scatter(a1[0], a1[1])
plt.scatter(a2[0], a2[1])
plt.scatter(2/3+a1[0], 2/3+a1[1])
plt.scatter(2/3+a2[0], 2/3+a2[1])
plt.show()
